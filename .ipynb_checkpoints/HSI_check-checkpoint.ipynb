# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import sys
import numpy as np
import random
from utils import *
from model import CSRNet
import torchvision.transforms as transforms
from DatasetConstructor import DatasetConstructor
import metrics
from PIL import Image
import time
SHANGHAITECH = "B"
# %matplotlib inline

# %%
# obtain the gpu device

assert torch.cuda.is_available()
cuda_device = torch.device("cuda")  # device object representing GPU

# %%
# data_load
img_dir = "/home/zzn/part_" + SHANGHAITECH + "_final/test_data/images"
gt_dir = "/home/zzn/part_" + SHANGHAITECH + "_final/test_data/gt_map"
dataset = DatasetConstructor(img_dir, gt_dir, 316, 316, False)
test_loader = torch.utils.data.DataLoader(dataset=dataset, batch_size=1)

# %%
mae_metrics = []
mse_metrics = []
images_tuple = []
net = torch.load("/home/zzn/Downloads/CSRNet_pytorch-master/checkpoints/model_1_rate_b_0318_14:07.pkl").to(cuda_device)
gt_process_model = GroundTruthProcess(1, 1, 8).to(cuda_device)
net.eval()


ae_batch = metrics.AEBatch().to(cuda_device)
se_batch = metrics.SEBatch().to(cuda_device)

# %%
for real_index, test_img, test_gt, test_time_cost in test_loader:
    image_shape = test_img.shape
    patch_height = int(image_shape[3])
    patch_width = int(image_shape[4])
    # B
    eval_x = test_img.view(49, 3, patch_height, patch_width)
    eval_y = test_gt.view(1, 1, patch_height * 4, patch_width * 4).cuda()
    eval_groundtruth = gt_process_model(eval_y)
                
    patch_height = int(patch_height / 8)
    patch_width = int(patch_width / 8)
    
    prediction_map = torch.zeros(1, 1, patch_height * 4, patch_width * 4).cuda()
    for i in range(7):
        for j in range(7):
            eval_x_sample = eval_x[i * 7 + j:i * 7 + j + 1].cuda()
            eval_prediction = net(eval_x_sample)
            start_h = int(patch_height / 4)
            start_w = int(patch_width / 4)
            valid_h = int(patch_height / 2)
            valid_w = int(patch_width / 2)
            h_pred = 3 * int(patch_height / 4) + 2 * int(patch_height / 4) * (i - 1)
            w_pred = 3 * int(patch_width / 4) + 2 * int(patch_width / 4) * (j - 1) 
            if i == 0:
                valid_h = int((3 * patch_height) / 4)
                start_h = 0
                h_pred = 0
            elif i == 6:
                valid_h = int((3 * patch_height) / 4)
                            
            if j == 0:
                valid_w = int((3 * patch_width) / 4)
                start_w = 0
                w_pred = 0
            elif j == 6:
                valid_w = int((3 * patch_width) / 4)
                        
            prediction_map[:, :, h_pred:h_pred + valid_h, w_pred:w_pred + valid_w] += eval_prediction[:, :, start_h:start_h + valid_h, start_w:start_w + valid_w]
    
    batch_ae = ae_batch(prediction_map, eval_groundtruth).data.cpu().numpy()
    batch_se = se_batch(prediction_map, eval_groundtruth).data.cpu().numpy()
    mae_metrics.append(batch_ae)
    mse_metrics.append(batch_se)
    # to numpy
    numpy_predict_map = prediction_map.permute(0, 2, 3, 1).data.cpu().numpy()
    numpy_gt_map = eval_groundtruth.permute(0, 2, 3, 1).data.cpu().numpy()
    
    gt_sum, predict_sum = np.sum(numpy_gt_map), np.sum(numpy_predict_map)
    rate = np.abs(gt_sum - predict_sum) / gt_sum
    images_tuple.append([real_index.numpy()[0], np.squeeze(numpy_gt_map), np.squeeze(numpy_predict_map), gt_sum, predict_sum, rate])

# %%
counts = 0
pred_counts_list = []
gt_counts_list = []

Hue_list = []
Saturation_list = []
Illumination_list = []
calcu = HSI_Calculator()

H_sum = 0
S_sum = 0
I_sum = 0

for index, gt_m, pred_m, gt_s, pred_s, r in images_tuple:
    H, S, I = calcu(Image.open("/home/zzn/part_B_final/test_data/images/IMG_" + str(index) + ".jpg"))
    H_sum += H
    S_sum += S
    I_sum += I
    if r >0.2:
        Hue_list.append(H)
        Saturation_list.append(S)
        Illumination_list.append(I)
        counts += 1
        # show current prediction
        figure, (origin, dm_gt, dm_pred) = plt.subplots(1, 3, figsize=(20, 4))
        origin.imshow(Image.open("/home/zzn/part_B_final/test_data/images/IMG_" + str(index) + ".jpg"))
        origin.set_title('Origin Image')
        dm_gt.imshow(gt_m, cmap=plt.cm.jet)
        dm_gt.set_title('ground_truth_1')
    
        dm_pred.imshow(pred_m, cmap=plt.cm.jet)
        dm_pred.set_title('prediction')
    
        plt.suptitle('The ' + str(index) + 'th images\'prediction')
        plt.show()
        plt.close()
        sys.stdout.write('The grount truth crowd number is:{}, and the predicting number is:{}, and rate is:{}'.format(gt_s, pred_s, r))
        sys.stdout.flush()
        pred_counts_list.append(pred_s)
        gt_counts_list.append(gt_s)
# Out:
# The grount truth crowd number is:224.0372772216797, and the predicting number is:272.0561828613281, and rate is:0.21433444321155548
# The grount truth crowd number is:9.0, and the predicting number is:12.539556503295898, and rate is:0.39328405261039734
# The grount truth crowd number is:81.44683837890625, and the predicting number is:42.113739013671875, and rate is:0.4829297363758087
# The grount truth crowd number is:92.5177230834961, and the predicting number is:45.085655212402344, and rate is:0.5126808881759644
# The grount truth crowd number is:127.70361328125, and the predicting number is:101.1801986694336, and rate is:0.2076950967311859
# The grount truth crowd number is:23.42142105102539, and the predicting number is:18.258567810058594, and rate is:0.22043296694755554
# The grount truth crowd number is:84.33379364013672, and the predicting number is:42.55154037475586, and rate is:0.4954390227794647
# ...

# %%
print(counts)
print(np.mean(pred_counts_list))
print(np.mean(gt_counts_list))
print("H:", np.mean(Hue_list))
print("S:", np.mean(Saturation_list))
print("I:", np.mean(Illumination_list))
print("H_all:", H_sum / 316)
print("S_all:", S_sum / 316)
print("I_all:", I_sum / 316)
# Out:
# 17
# 112.15432
# 125.775
# H: 0.43034285
# S: 0.15276988
# I: 0.4044562
# H_all: tensor(0.4137)
# S_all: tensor(0.1350)
# I_all: tensor(0.4320)

# %%
mae_metrics = np.reshape(mae_metrics, [-1])
mse_metrics = np.reshape(mse_metrics, [-1])
MAE = np.mean(mae_metrics)
MSE = np.sqrt(np.mean(mse_metrics))
print('MAE:', MAE, 'MSE:', MSE)
# Out:
# MAE: 10.111514 MSE: 16.510456
